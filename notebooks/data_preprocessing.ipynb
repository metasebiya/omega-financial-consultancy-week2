# %% [markdown]
# ## # Exploratory Data Analysis on Customer Review Data at Omega Consultancy
# ## 1. Import Libraries and utility functions

# %%
import sys
import os

notebook_dir = os.getcwd()  # Get current working directory (notebooks folder)
project_dir = os.path.abspath(os.path.join(notebook_dir, '..'))  # Go up one level
src_dir = os.path.join(project_dir, 'src')  # Path to scripts
sys.path.append(src_dir)

# %%
from IPython.display import display
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from load_data import DataLoader
from clean_data import DataCleaner

# %% [markdown]
# ## 2. Importing Customer Review Data

# %%
customer_review = {
        "CBE": "../data/raw/Commercial Bank of Ethiopia_reviews.csv",
        "BOA": "../data/raw/BoA Mobile_reviews.csv",
        "Dashen": "../data/raw/Dashen Bank_reviews.csv"
    }
all_data = DataLoader.load_data(customer_review,customer_review)

# %%
print(all_data)
# Out:
# {'CBE':                                             Review Text  Rating  \
# 0                                                 dedeb       5
# 1                                                  good       5
# 2                                                  Good       5
# 3                                                    👌👍       5
# 4                                             very niec       5
# ...                                                 ...     ...
# 1995                                               Nice       5
# 1996  Still needs development on several features......       1
# 1997                  Good service at Baburehama branch       5
# 1998          First and best Online banking in Ethiopia       5
# 1999                                               Good       5
#
#                      Date                Bank/App Name       Source
# 0     2025-06-04 15:04:02  Commercial Bank of Ethiopia  Google Play
# 1     2025-06-04 14:59:40  Commercial Bank of Ethiopia  Google Play
# 2     2025-06-04 14:52:50  Commercial Bank of Ethiopia  Google Play
# 3     2025-06-04 12:43:21  Commercial Bank of Ethiopia  Google Play
# 4     2025-06-04 11:21:53  Commercial Bank of Ethiopia  Google Play
# ...                   ...                          ...          ...
# 1995  2024-08-27 11:00:48  Commercial Bank of Ethiopia  Google Play
# 1996  2024-08-27 10:44:29  Commercial Bank of Ethiopia  Google Play
# 1997  2024-08-27 08:58:25  Commercial Bank of Ethiopia  Google Play
# 1998  2024-08-26 20:38:12  Commercial Bank of Ethiopia  Google Play
# 1999  2024-08-26 18:44:43  Commercial Bank of Ethiopia  Google Play
#
# [2000 rows x 5 columns], 'BOA':                                             Review Text  Rating  \
# 0     Hello, I’m facing a problem with the BOA Mobil...       1
# 1                                           exceptional       5
# 2                                  BoA Mobile good bank       5
# 3                       this is worest app 24/7 loading       1
# 4     This App is not interest for Android phone Ple...       1
# ...                                                 ...     ...
# 1039                                        Perfect app       5
# 1040                                                  👍       3
# 1041  Absolutely it's fantastic apps this New apps i...       5
# 1042         The best app next to Tele birr in ethiopia       5
# 1043                                                  👍       5
#
#                      Date Bank/App Name       Source
# 0     2025-06-03 16:21:34    BoA Mobile  Google Play
# 1     2025-06-03 10:32:35    BoA Mobile  Google Play
# 2     2025-06-02 14:25:12    BoA Mobile  Google Play
# 3     2025-06-01 15:51:10    BoA Mobile  Google Play
# 4     2025-06-01 10:17:10    BoA Mobile  Google Play
# ...                   ...           ...          ...
# 1039  2024-01-12 11:10:38    BoA Mobile  Google Play
# 1040  2024-01-11 21:04:51    BoA Mobile  Google Play
# 1041  2024-01-11 20:49:53    BoA Mobile  Google Play
# 1042  2024-01-10 21:09:40    BoA Mobile  Google Play
# 1043  2024-01-10 09:20:59    BoA Mobile  Google Play
#
# [1044 rows x 5 columns], 'Dashen':                                            Review Text  Rating  \
# 0                                                 መቸሸጠ       5
# 1                                                  wow       5
# 2                                                gadaa       5
# 3                  Massive upgrade from the Amole app.       5
# 4                                                 good       4
# ..                                                 ...     ...
# 444                                               Best       5
# 445  Waw Great and innovated,user friendly, always ...       5
# 446                                   It's Best waww 🙏       5
# 447                              Always one step ahead       5
# 448       Like Me, I Hope It Works Better Than Before.       5
#
#                     Date Bank/App Name       Source
# 0    2025-06-03 19:40:31   Dashen Bank  Google Play
# 1    2025-06-03 17:30:11   Dashen Bank  Google Play
# 2    2025-06-01 17:10:53   Dashen Bank  Google Play
# 3    2025-05-31 23:04:04   Dashen Bank  Google Play
# 4    2025-05-31 22:39:35   Dashen Bank  Google Play
# ..                   ...           ...          ...
# 444  2025-01-13 21:11:58   Dashen Bank  Google Play
# 445  2025-01-13 21:01:12   Dashen Bank  Google Play
# 446  2025-01-13 09:37:19   Dashen Bank  Google Play
# 447  2025-01-13 09:15:03   Dashen Bank  Google Play
# 448  2025-01-11 11:36:49   Dashen Bank  Google Play
#
# [449 rows x 5 columns]}

# %% [markdown]
# ### 3. Cleaning Data

# %%
cleaner = DataCleaner(output_dir="../data/processed/")
for key, data in all_data.items():
    cleaned_data = cleaner.clean_data(data, key)
    print(cleaned_data)
# Out:
# 📊 Data Description:
#             Rating
# count  2000.000000
# mean      4.150500
# std       1.440447
# min       1.000000
# 25%       4.000000
# 50%       5.000000
# 75%       5.000000
# max       5.000000
# Columns in the DataFrame:
# ['Review Text', 'Rating', 'Date', 'Bank/App Name', 'Source']
# Columns after renaming: ['review_text', 'rating', 'date', 'bank_name', 'source']
#
# 🧱 Shape: (2000, 5) (rows, columns)
# 📦 Size: 10000 (total elements)
#
# 🧱 Data Types of the df: review_text    object
# rating          int64
# date           object
# bank_name      object
# source         object
# dtype: object
#
# 🧱 Info of the DF: <bound method DataFrame.info of                                             review_text  rating  \
# 0                                                 dedeb       5
# 1                                                  good       5
# 2                                                  Good       5
# 3                                                    👌👍       5
# 4                                             very niec       5
# ...                                                 ...     ...
# 1995                                               Nice       5
# 1996  Still needs development on several features......       1
# 1997                  Good service at Baburehama branch       5
# 1998          First and best Online banking in Ethiopia       5
# 1999                                               Good       5
#
#                      date                    bank_name       source
# 0     2025-06-04 15:04:02  Commercial Bank of Ethiopia  Google Play
# 1     2025-06-04 14:59:40  Commercial Bank of Ethiopia  Google Play
# 2     2025-06-04 14:52:50  Commercial Bank of Ethiopia  Google Play
# 3     2025-06-04 12:43:21  Commercial Bank of Ethiopia  Google Play
# 4     2025-06-04 11:21:53  Commercial Bank of Ethiopia  Google Play
# ...                   ...                          ...          ...
# 1995  2024-08-27 11:00:48  Commercial Bank of Ethiopia  Google Play
# 1996  2024-08-27 10:44:29  Commercial Bank of Ethiopia  Google Play
# 1997  2024-08-27 08:58:25  Commercial Bank of Ethiopia  Google Play
# 1998  2024-08-26 20:38:12  Commercial Bank of Ethiopia  Google Play
# 1999  2024-08-26 18:44:43  Commercial Bank of Ethiopia  Google Play
#
# [2000 rows x 5 columns]>
#
# 🧱 Duplicated Values: 0
#
# 🕳️ Missing Values Per Column:
# review_text    0
# rating         0
# date           0
# bank_name      0
# source         0
# dtype: int64
#  Normalized 'at' column to 'date' (YYYY-MM-DD).0       2025-06-04
# 1       2025-06-04
# 2       2025-06-04
# 3       2025-06-04
# 4       2025-06-04
#            ...
# 1995    2024-08-27
# 1996    2024-08-27
# 1997    2024-08-27
# 1998    2024-08-26
# 1999    2024-08-26
# Name: date, Length: 2000, dtype: object
#
# ✅ Data cleaning complete.
# 🔄 Existing file 'CBE_review_cleaned.csv' found and removed.
# ✅ DataFrame successfully saved to: ../data/processed/CBE_review_cleaned.csv
#                                             review_text  rating        date  \
# 0                                                 dedeb       5  2025-06-04
# 1                                                  good       5  2025-06-04
# 2                                                  Good       5  2025-06-04
# 3                                                    👌👍       5  2025-06-04
# 4                                             very niec       5  2025-06-04
# ...                                                 ...     ...         ...
# 1995                                               Nice       5  2024-08-27
# 1996  Still needs development on several features......       1  2024-08-27
# 1997                  Good service at Baburehama branch       5  2024-08-27
# 1998          First and best Online banking in Ethiopia       5  2024-08-26
# 1999                                               Good       5  2024-08-26
#
#                         bank_name       source
# 0     Commercial Bank of Ethiopia  Google Play
# 1     Commercial Bank of Ethiopia  Google Play
# 2     Commercial Bank of Ethiopia  Google Play
# 3     Commercial Bank of Ethiopia  Google Play
# 4     Commercial Bank of Ethiopia  Google Play
# ...                           ...          ...
# 1995  Commercial Bank of Ethiopia  Google Play
# 1996  Commercial Bank of Ethiopia  Google Play
# 1997  Commercial Bank of Ethiopia  Google Play
# 1998  Commercial Bank of Ethiopia  Google Play
# 1999  Commercial Bank of Ethiopia  Google Play
#
# [2000 rows x 5 columns]
#
# 📊 Data Description:
#             Rating
# count  1044.000000
# mean      3.065134
# std       1.861857
# min       1.000000
# 25%       1.000000
# 50%       3.000000
# 75%       5.000000
# max       5.000000
# Columns in the DataFrame:
# ['Review Text', 'Rating', 'Date', 'Bank/App Name', 'Source']
# Columns after renaming: ['review_text', 'rating', 'date', 'bank_name', 'source']
#
# 🧱 Shape: (1044, 5) (rows, columns)
# 📦 Size: 5220 (total elements)
#
# 🧱 Data Types of the df: review_text    object
# rating          int64
# date           object
# bank_name      object
# source         object
# dtype: object
#
# 🧱 Info of the DF: <bound method DataFrame.info of                                             review_text  rating  \
# 0     Hello, I’m facing a problem with the BOA Mobil...       1
# 1                                           exceptional       5
# 2                                  BoA Mobile good bank       5
# 3                       this is worest app 24/7 loading       1
# 4     This App is not interest for Android phone Ple...       1
# ...                                                 ...     ...
# 1039                                        Perfect app       5
# 1040                                                  👍       3
# 1041  Absolutely it's fantastic apps this New apps i...       5
# 1042         The best app next to Tele birr in ethiopia       5
# 1043                                                  👍       5
#
#                      date   bank_name       source
# 0     2025-06-03 16:21:34  BoA Mobile  Google Play
# 1     2025-06-03 10:32:35  BoA Mobile  Google Play
# 2     2025-06-02 14:25:12  BoA Mobile  Google Play
# 3     2025-06-01 15:51:10  BoA Mobile  Google Play
# 4     2025-06-01 10:17:10  BoA Mobile  Google Play
# ...                   ...         ...          ...
# 1039  2024-01-12 11:10:38  BoA Mobile  Google Play
# 1040  2024-01-11 21:04:51  BoA Mobile  Google Play
# 1041  2024-01-11 20:49:53  BoA Mobile  Google Play
# 1042  2024-01-10 21:09:40  BoA Mobile  Google Play
# 1043  2024-01-10 09:20:59  BoA Mobile  Google Play
#
# [1044 rows x 5 columns]>
#
# 🧱 Duplicated Values: 0
#
# 🕳️ Missing Values Per Column:
# review_text    0
# rating         0
# date           0
# bank_name      0
# source         0
# dtype: int64
#  Normalized 'at' column to 'date' (YYYY-MM-DD).0       2025-06-03
# 1       2025-06-03
# 2       2025-06-02
# 3       2025-06-01
# 4       2025-06-01
#            ...
# 1039    2024-01-12
# 1040    2024-01-11
# 1041    2024-01-11
# 1042    2024-01-10
# 1043    2024-01-10
# Name: date, Length: 1044, dtype: object
#
# ✅ Data cleaning complete.
# 🔄 Existing file 'BOA_review_cleaned.csv' found and removed.
# ✅ DataFrame successfully saved to: ../data/processed/BOA_review_cleaned.csv
#                                             review_text  rating        date  \
# 0     Hello, I’m facing a problem with the BOA Mobil...       1  2025-06-03
# 1                                           exceptional       5  2025-06-03
# 2                                  BoA Mobile good bank       5  2025-06-02
# 3                       this is worest app 24/7 loading       1  2025-06-01
# 4     This App is not interest for Android phone Ple...       1  2025-06-01
# ...                                                 ...     ...         ...
# 1039                                        Perfect app       5  2024-01-12
# 1040                                                  👍       3  2024-01-11
# 1041  Absolutely it's fantastic apps this New apps i...       5  2024-01-11
# 1042         The best app next to Tele birr in ethiopia       5  2024-01-10
# 1043                                                  👍       5  2024-01-10
#
#        bank_name       source
# 0     BoA Mobile  Google Play
# 1     BoA Mobile  Google Play
# 2     BoA Mobile  Google Play
# 3     BoA Mobile  Google Play
# 4     BoA Mobile  Google Play
# ...          ...          ...
# 1039  BoA Mobile  Google Play
# 1040  BoA Mobile  Google Play
# 1041  BoA Mobile  Google Play
# 1042  BoA Mobile  Google Play
# 1043  BoA Mobile  Google Play
#
# [1044 rows x 5 columns]
#
# 📊 Data Description:
#            Rating
# count  449.000000
# mean     4.478842
# std      1.199003
# min      1.000000
# 25%      5.000000
# 50%      5.000000
# 75%      5.000000
# max      5.000000
# Columns in the DataFrame:
# ['Review Text', 'Rating', 'Date', 'Bank/App Name', 'Source']
# Columns after renaming: ['review_text', 'rating', 'date', 'bank_name', 'source']
#
# 🧱 Shape: (449, 5) (rows, columns)
# 📦 Size: 2245 (total elements)
#
# 🧱 Data Types of the df: review_text    object
# rating          int64
# date           object
# bank_name      object
# source         object
# dtype: object
#
# 🧱 Info of the DF: <bound method DataFrame.info of                                            review_text  rating  \
# 0                                                 መቸሸጠ       5
# 1                                                  wow       5
# 2                                                gadaa       5
# 3                  Massive upgrade from the Amole app.       5
# 4                                                 good       4
# ..                                                 ...     ...
# 444                                               Best       5
# 445  Waw Great and innovated,user friendly, always ...       5
# 446                                   It's Best waww 🙏       5
# 447                              Always one step ahead       5
# 448       Like Me, I Hope It Works Better Than Before.       5
#
#                     date    bank_name       source
# 0    2025-06-03 19:40:31  Dashen Bank  Google Play
# 1    2025-06-03 17:30:11  Dashen Bank  Google Play
# 2    2025-06-01 17:10:53  Dashen Bank  Google Play
# 3    2025-05-31 23:04:04  Dashen Bank  Google Play
# 4    2025-05-31 22:39:35  Dashen Bank  Google Play
# ..                   ...          ...          ...
# 444  2025-01-13 21:11:58  Dashen Bank  Google Play
# 445  2025-01-13 21:01:12  Dashen Bank  Google Play
# 446  2025-01-13 09:37:19  Dashen Bank  Google Play
# 447  2025-01-13 09:15:03  Dashen Bank  Google Play
# 448  2025-01-11 11:36:49  Dashen Bank  Google Play
#
# [449 rows x 5 columns]>
#
# 🧱 Duplicated Values: 0
#
# 🕳️ Missing Values Per Column:
# review_text    0
# rating         0
# date           0
# bank_name      0
# source         0
# dtype: int64
#  Normalized 'at' column to 'date' (YYYY-MM-DD).0      2025-06-03
# 1      2025-06-03
# 2      2025-06-01
# 3      2025-05-31
# 4      2025-05-31
#           ...
# 444    2025-01-13
# 445    2025-01-13
# 446    2025-01-13
# 447    2025-01-13
# 448    2025-01-11
# Name: date, Length: 449, dtype: object
#
# ✅ Data cleaning complete.
# 🔄 Existing file 'Dashen_review_cleaned.csv' found and removed.
# ✅ DataFrame successfully saved to: ../data/processed/Dashen_review_cleaned.csv
#                                            review_text  rating        date  \
# 0                                                 መቸሸጠ       5  2025-06-03
# 1                                                  wow       5  2025-06-03
# 2                                                gadaa       5  2025-06-01
# 3                  Massive upgrade from the Amole app.       5  2025-05-31
# 4                                                 good       4  2025-05-31
# ..                                                 ...     ...         ...
# 444                                               Best       5  2025-01-13
# 445  Waw Great and innovated,user friendly, always ...       5  2025-01-13
# 446                                   It's Best waww 🙏       5  2025-01-13
# 447                              Always one step ahead       5  2025-01-13
# 448       Like Me, I Hope It Works Better Than Before.       5  2025-01-11
#
#        bank_name       source
# 0    Dashen Bank  Google Play
# 1    Dashen Bank  Google Play
# 2    Dashen Bank  Google Play
# 3    Dashen Bank  Google Play
# 4    Dashen Bank  Google Play
# ..           ...          ...
# 444  Dashen Bank  Google Play
# 445  Dashen Bank  Google Play
# 446  Dashen Bank  Google Play
# 447  Dashen Bank  Google Play
# 448  Dashen Bank  Google Play
#
# [449 rows x 5 columns]
